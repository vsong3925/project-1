# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key
import json
import pandas as pd
import glob

# %% [markdown]
# ### 1) API: Requests URL & Create CSV File

# %% [markdown]
# #### API: American Community Survey 1-Year Data (2005-2019) - State Level

# %%
# Create csv file for individual year from 2009 to 2019

# Means of Transportation
years = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
variable = 'B08101_001E'
title = 'transportation'

for year in years:
    url = f'https://api.census.gov/data/{year}/acs/acs1?get=NAME,{variable}&for=state:*&key={api_key}'
    data = requests.get(url).json()
    col_name = ['state', year, 'state code']
    df = pd.DataFrame(data[1:], columns=col_name)
    clean_df = df.drop(columns=['state code'])
    clean_df.to_csv(f'{year}_{title}.csv')

# %%
# Worked From Home
years = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
variable = 'B08101_049E'
title = 'worked_fm_home'

for year in years:
    url = f'https://api.census.gov/data/{year}/acs/acs1?get=NAME,{variable}&for=state:*&key={api_key}'
    data = requests.get(url).json()
    col_name = ['state', year, 'state code']
    df = pd.DataFrame(data[1:], columns=col_name)
    clean_df = df.drop(columns=['state code'])
    clean_df.to_csv(f'{year}_{title}.csv')

# %%
# Drove Alone
years = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
variable = 'B08101_009E'
title = 'drove'

for year in years:
    url = f'https://api.census.gov/data/{year}/acs/acs1?get=NAME,{variable}&for=state:*&key={api_key}'
    data = requests.get(url).json()
    col_name = ['state', year, 'state code']
    df = pd.DataFrame(data[1:], columns=col_name)
    clean_df = df.drop(columns=['state code'])
    clean_df.to_csv(f'{year}_{title}.csv')

# %%
# Carpooled
years = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
variable = 'B08101_017E'
title = 'carpooled'

for year in years:
    url = f'https://api.census.gov/data/{year}/acs/acs1?get=NAME,{variable}&for=state:*&key={api_key}'
    data = requests.get(url).json()
    col_name = ['state', year, 'state code']
    df = pd.DataFrame(data[1:], columns=col_name)
    clean_df = df.drop(columns=['state code'])
    clean_df.to_csv(f'{year}_{title}.csv')

# %%
# Walked
years = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
variable = 'B08101_033E'
title = 'walked'

for year in years:
    url = f'https://api.census.gov/data/{year}/acs/acs1?get=NAME,{variable}&for=state:*&key={api_key}'
    data = requests.get(url).json()
    col_name = ['state', year, 'state code']
    df = pd.DataFrame(data[1:], columns=col_name)
    clean_df = df.drop(columns=['state code'])
    clean_df.to_csv(f'{year}_{title}.csv')

# %%
# Public Transportation (Excluding Taxi)
years = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
variable = 'B08101_025E'
title = 'public_transportation'

for year in years:
    url = f'https://api.census.gov/data/{year}/acs/acs1?get=NAME,{variable}&for=state:*&key={api_key}'
    data = requests.get(url).json()
    col_name = ['state', year, 'state code']
    df = pd.DataFrame(data[1:], columns=col_name)
    clean_df = df.drop(columns=['state code'])
    clean_df.to_csv(f'{year}_{title}.csv')

# %%
# Taxi, Motercycle, Bicycle
years = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
variable = 'B08101_041E'
title = 'taxi_bikes'

for year in years:
    url = f'https://api.census.gov/data/{year}/acs/acs1?get=NAME,{variable}&for=state:*&key={api_key}'
    data = requests.get(url).json()
    col_name = ['state', year, 'state code']
    df = pd.DataFrame(data[1:], columns=col_name)
    clean_df = df.drop(columns=['state code'])
    clean_df.to_csv(f'{year}_{title}.csv')

# %% [markdown]
# ### 2) Read CSV Files

# %%
# Toal Means of Transportation
df = pd.read_csv('2009_transportation.csv')
df_2009 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2010_transportation.csv')
df_2010 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2011_transportation.csv')
df_2011 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2012_transportation.csv')
df_2012 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2013_transportation.csv')
df_2013 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2014_transportation.csv')
df_2014 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2015_transportation.csv')
df_2015 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2016_transportation.csv')
df_2016 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2017_transportation.csv')
df_2017 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2018_transportation.csv')
df_2018 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2019_transportation.csv')
df_2019 = df.drop(columns=['Unnamed: 0'])

dfs = [df.set_index(['state']) for df in [df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019]]
transportation_dfs = pd.concat(dfs, axis=1)
transportation_df = transportation_dfs.rename(columns={'index':'state'})
va_transportation = pd.DataFrame(transportation_df.loc['Virginia'])
va_transportation.head()
# Out:
#       Virginia
# 2009   3822714
# 2010   3845626
# 2011   3883249
# 2012   3967188
# 2013   4018400

# %%
# Worked From Home
df = pd.read_csv('2009_worked_fm_home.csv')
df_2009 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2010_worked_fm_home.csv')
df_2010 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2011_worked_fm_home.csv')
df_2011 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2012_worked_fm_home.csv')
df_2012 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2013_worked_fm_home.csv')
df_2013 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2014_worked_fm_home.csv')
df_2014 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2015_worked_fm_home.csv')
df_2015 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2016_worked_fm_home.csv')
df_2016 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2017_worked_fm_home.csv')
df_2017 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2018_worked_fm_home.csv')
df_2018 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv('2019_worked_fm_home.csv')
df_2019 = df.drop(columns=['Unnamed: 0'])

dfs = [df.set_index(['state']) for df in [df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019]]
worked_fm_home_dfs = pd.concat(dfs, axis=1)
worked_fm_home_df = worked_fm_home_dfs.rename(columns={'index':'state'})
va_worked_fm_home = pd.DataFrame(worked_fm_home_df.loc['Virginia'])
va_worked_fm_home.head()
# Out:
#       Virginia
# 2009    157174
# 2010    167035
# 2011    176921
# 2012    187750
# 2013    182279

# %%
# Drove
title = 'drove'

df = pd.read_csv(f'2009_{title}.csv')
df_2009 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2010_{title}.csv')
df_2010 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2011_{title}.csv')
df_2011 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2012_{title}.csv')
df_2012 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2013_{title}.csv')
df_2013 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2014_{title}.csv')
df_2014 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2015_{title}.csv')
df_2015 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2016_{title}.csv')
df_2016 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2017_{title}.csv')
df_2017 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2018_{title}.csv')
df_2018 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2019_{title}.csv')
df_2019 = df.drop(columns=['Unnamed: 0'])

dfs = [df.set_index(['state']) for df in [df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019]]
drove_dfs = pd.concat(dfs, axis=1)
drove_df = drove_dfs.rename(columns={'index':'state'})
va_drove = pd.DataFrame(drove_df.loc['Virginia'])
va_drove.head()
# Out:
#       Virginia
# 2009   2962941
# 2010   2966482
# 2011   3032187
# 2012   3067222
# 2013   3112188

# %%
# Carpooled
title = 'carpooled'

df = pd.read_csv(f'2009_{title}.csv')
df_2009 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2010_{title}.csv')
df_2010 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2011_{title}.csv')
df_2011 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2012_{title}.csv')
df_2012 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2013_{title}.csv')
df_2013 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2014_{title}.csv')
df_2014 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2015_{title}.csv')
df_2015 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2016_{title}.csv')
df_2016 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2017_{title}.csv')
df_2017 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2018_{title}.csv')
df_2018 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2019_{title}.csv')
df_2019 = df.drop(columns=['Unnamed: 0'])

dfs = [df.set_index(['state']) for df in [df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019]]
carpooled_dfs = pd.concat(dfs, axis=1)
carpooled_df = carpooled_dfs.rename(columns={'index':'state'})
va_carpooled = pd.DataFrame(carpooled_df.loc['Virginia'])
va_carpooled.head()
# Out:
#       Virginia
# 2009    396824
# 2010    383909
# 2011    355426
# 2012    393282
# 2013    376679

# %%
# Walked
title = 'walked'

df = pd.read_csv(f'2009_{title}.csv')
df_2009 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2010_{title}.csv')
df_2010 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2011_{title}.csv')
df_2011 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2012_{title}.csv')
df_2012 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2013_{title}.csv')
df_2013 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2014_{title}.csv')
df_2014 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2015_{title}.csv')
df_2015 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2016_{title}.csv')
df_2016 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2017_{title}.csv')
df_2017 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2018_{title}.csv')
df_2018 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2019_{title}.csv')
df_2019 = df.drop(columns=['Unnamed: 0'])

dfs = [df.set_index(['state']) for df in [df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019]]
walked_dfs = pd.concat(dfs, axis=1)
walked_df = walked_dfs.rename(columns={'index':'state'})
va_walked = pd.DataFrame(walked_df.loc['Virginia'])
va_walked.head()
# Out:
#       Virginia
# 2009     85818
# 2010    103982
# 2011     90716
# 2012     87938
# 2013     99433

# %%
# Public Transportation
title = 'public_transportation'

df = pd.read_csv(f'2009_{title}.csv')
df_2009 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2010_{title}.csv')
df_2010 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2011_{title}.csv')
df_2011 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2012_{title}.csv')
df_2012 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2013_{title}.csv')
df_2013 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2014_{title}.csv')
df_2014 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2015_{title}.csv')
df_2015 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2016_{title}.csv')
df_2016 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2017_{title}.csv')
df_2017 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2018_{title}.csv')
df_2018 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2019_{title}.csv')
df_2019 = df.drop(columns=['Unnamed: 0'])

dfs = [df.set_index(['state']) for df in [df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019]]
public_transportation_dfs = pd.concat(dfs, axis=1)
public_transportation_df = public_transportation_dfs.rename(columns={'index':'state'})
public_transportation = pd.DataFrame(public_transportation_df.loc['Virginia'])
public_transportation.head()
# Out:
#       Virginia
# 2009    168359
# 2010    168554
# 2011    174888
# 2012    174525
# 2013    176996

# %%
# Taxi Bikes
title = 'taxi_bikes'

df = pd.read_csv(f'2009_{title}.csv')
df_2009 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2010_{title}.csv')
df_2010 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2011_{title}.csv')
df_2011 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2012_{title}.csv')
df_2012 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2013_{title}.csv')
df_2013 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2014_{title}.csv')
df_2014 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2015_{title}.csv')
df_2015 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2016_{title}.csv')
df_2016 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2017_{title}.csv')
df_2017 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2018_{title}.csv')
df_2018 = df.drop(columns=['Unnamed: 0'])

df = pd.read_csv(f'2019_{title}.csv')
df_2019 = df.drop(columns=['Unnamed: 0'])

dfs = [df.set_index(['state']) for df in [df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019]]
taxi_bikes_dfs = pd.concat(dfs, axis=1)
taxi_bikes_df = taxi_bikes_dfs.rename(columns={'index':'state'})
taxi_bikes = pd.DataFrame(taxi_bikes_df.loc['Virginia'])
taxi_bikes.head()
# Out:
#       Virginia
# 2009     51598
# 2010     55664
# 2011     53111
# 2012     56471
# 2013     70825

# %% [markdown]
# ### 3) Create DataFrame

# %%
# Read SAEXP1__ALL_AREAS_1997_2019.csv
# Create DataFrame: VA Personal Expense
file = 'SAEXP1__ALL_AREAS_1997_2019.csv'
data = pd.read_csv(file)
data.head()

data2 = data[['GeoName', 'Description','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']]
data3 = data2.set_index('GeoName')

va_data = data3.loc['Virginia']
description_va_data = va_data.set_index('Description')
description_va_data.head()
# Motor vehicles and parts
# Transportation services
# Out:
#                                                     2009      2010      2011  \
# Description
# Personal consumption expenditures               278116.8  288202.1  300020.4
#  Goods                                           87868.2   91921.6   96899.8
#   Durable goods                                  28420.3   29391.6   30385.6
#    Motor vehicles and parts                       9354.1   10111.9   10432.5
#    Furnishings and durable household equipment    6799.2    6862.7    7093.6
#
#                                                     2012      2013      2014  \
# Description
# Personal consumption expenditures               311126.8  318739.0  330649.0
#  Goods                                           99855.9  101347.6  102661.6
#   Durable goods                                  31614.4   32564.8   33264.2
#    Motor vehicles and parts                      11177.3   11539.5   11982.4
#    Furnishings and durable household equipment    7281.8    7519.6    7703.7
#
#                                                     2015      2016      2017  \
# Description
# Personal consumption expenditures               342044.5  354923.9  368824.0
#  Goods                                          103521.5  104621.6  108887.5
#   Durable goods                                  34681.1   35326.8   36447.6
#    Motor vehicles and parts                      12795.3   13148.2   13434.8
#    Furnishings and durable household equipment    8169.0    8423.9    8774.7
#
#                                                     2018      2019
# Description
# Personal consumption expenditures               384556.4  397230.5
#  Goods                                          113397.6  117126.9
#   Durable goods                                  38212.4   39843.1
#    Motor vehicles and parts                      13952.1   14016.2
#    Furnishings and durable household equipment    9145.4    9441.3

# %%
# DataFrame: Means of Transportation (Population)
va_transportation_df = va_transportation.rename(columns={'Virginia':'All Transporation'})
va_worked_fm_home_df = va_worked_fm_home.rename(columns={'Virginia':'Worked fm Home'})
va_drove_df = va_drove.rename(columns={'Virginia':'Drove'})
va_carpooled_df = va_carpooled.rename(columns={'Virginia':'Carpooled'})
va_walked_df = va_walked.rename(columns={'Virginia':'Walked'})
public_transportation_df = public_transportation.rename(columns={'Virginia':'Public Transportation'})
taxi_bikes_df = taxi_bikes.rename(columns={'Virginia':'Taxi and Bikes'})

df = pd.concat([va_transportation_df, va_worked_fm_home_df, va_drove_df, va_carpooled_df, va_walked_df, public_transportation_df, taxi_bikes_df], axis=1)
df.head()
# Out:
#       All Transporation  Worked fm Home    Drove  Carpooled  Walked  \
# 2009            3822714          157174  2962941     396824   85818
# 2010            3845626          167035  2966482     383909  103982
# 2011            3883249          176921  3032187     355426   90716
# 2012            3967188          187750  3067222     393282   87938
# 2013            4018400          182279  3112188     376679   99433
#
#       Public Transportation  Taxi and Bikes
# 2009                 168359           51598
# 2010                 168554           55664
# 2011                 174888           53111
# 2012                 174525           56471
# 2013                 176996           70825

# %%
# Merge two DataFrames
motor_vehicles_and_parts = pd.DataFrame(description_va_data.iloc[3])
transportation_services = pd.DataFrame(description_va_data.iloc[16])

complete_data = pd.concat([motor_vehicles_and_parts, transportation_services, df], axis=1)
complete_data.head()
# Out:
#          Motor vehicles and parts     Transportation services  \
# 2009                       9354.1                      6699.5
# 2010                      10111.9                      6992.7
# 2011                      10432.5                      7630.0
# 2012                      11177.3                      7943.6
# 2013                      11539.5                      8249.7
#
#       All Transporation  Worked fm Home    Drove  Carpooled  Walked  \
# 2009            3822714          157174  2962941     396824   85818
# 2010            3845626          167035  2966482     383909  103982
# 2011            3883249          176921  3032187     355426   90716
# 2012            3967188          187750  3067222     393282   87938
# 2013            4018400          182279  3112188     376679   99433
#
#       Public Transportation  Taxi and Bikes
# 2009                 168359           51598
# 2010                 168554           55664
# 2011                 174888           53111
# 2012                 174525           56471
# 2013                 176996           70825

# %% [markdown]
# ### 4) Visualize and Plot Data

# %%
# Display the dataframe for reference
complete_data.head()
# Out:
#          Motor vehicles and parts     Transportation services  \
# 2009                       9354.1                      6699.5
# 2010                      10111.9                      6992.7
# 2011                      10432.5                      7630.0
# 2012                      11177.3                      7943.6
# 2013                      11539.5                      8249.7
#
#       All Transporation  Worked fm Home    Drove  Carpooled  Walked  \
# 2009            3822714          157174  2962941     396824   85818
# 2010            3845626          167035  2966482     383909  103982
# 2011            3883249          176921  3032187     355426   90716
# 2012            3967188          187750  3067222     393282   87938
# 2013            4018400          182279  3112188     376679   99433
#
#       Public Transportation  Taxi and Bikes
# 2009                 168359           51598
# 2010                 168554           55664
# 2011                 174888           53111
# 2012                 174525           56471
# 2013                 176996           70825

# %% [markdown]
# #### 4.1) Motor Vehicles and Parts Expenditures vs. Drove and Carpooled Population

# %%
# Expenditure and Population Comparison
year = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
# Expenditures
motor_vehicles = complete_data.iloc[:,0]
transportation_sservice = complete_data.iloc[:,1]

# Populations
total_driving = complete_data['Drove'] + complete_data['Carpooled']
total_public = complete_data['Public Transportation'] + complete_data['Taxi and Bikes']

# Plot
fig, (ax1,ax2) = plt.subplots(nrows=2, ncols=1, sharex=True) 
ax1.plot(year, motor_vehicles, color = 'coral', linestyle = '--', label='expenditures')
ax2.plot(year, total_driving, color = 'coral', label='population')

ax1.legend()
ax1.set_title('Motor Vehicles and Parts')
ax1.set_xlabel('Years')
ax1.set_ylabel('Expenditure')

ax2.legend()
ax2.set_xlabel('Years')
ax2.set_ylabel('Population')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.2) Public Transportation Expenditures vs. Public Transportation Population

# %%
# Expenditure and Population Comparison

year = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
# Expenditures
transportation_sservice = complete_data.iloc[:,1]
# Populations
public_transportation = complete_data['Public Transportation']

# Plot
fig, (ax1,ax2) = plt.subplots(nrows=2, ncols=1, sharex=True) 
ax1.plot(year, transportation_sservice, color='steelblue', linestyle='--', label='expenditures')
ax2.plot(year, public_transportation, color = 'steelblue', label='population')


ax1.legend()
ax1.set_title('Public Transportation')
ax1.set_xlabel('Years')
ax1.set_ylabel('Expenditure')

ax2.legend()
ax2.set_xlabel('Years')
ax2.set_ylabel('Population')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.3) Public Transportation Popluation vs. Taxi/Bikes Population

# %%
# Compare Transportation Service Expense with Public Transportation Population
# Create line plot for comparison
year = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']

public_transporation = complete_data['Public Transportation']
taxi_bikes = complete_data['Taxi and Bikes']

fig, ax1 = plt.subplots() #(nrows=2, ncols=1, sharex=True) 
#ax1.plot(year, public_transportation, color = 'coral', label='Public Transportation')
ax1.plot(year, taxi_bikes, color = 'coral', linestyle='--', label='Taxi and Bikes')

ax1.legend()
ax1.set_title('Taxi and Bikes')
ax1.set_xlabel('Years')
ax1.set_ylabel('Expenditure')

#ax2.legend()
#ax2.set_xlabel('Years')
#ax2.set_ylabel('Population')

plt.tight_layout()
plt.show()

# fig.savefig('Compare_Worked fm Home vs. Walk to Work.png')

# %% [markdown]
# #### 4.4) Percentage Comparison: Motor Vehicles and Parts vs. Public Transportation Expenditures

# %%
complete_data
# Out:
#          Motor vehicles and parts     Transportation services  \
# 2009                       9354.1                      6699.5
# 2010                      10111.9                      6992.7
# 2011                      10432.5                      7630.0
# 2012                      11177.3                      7943.6
# 2013                      11539.5                      8249.7
# 2014                      11982.4                      8472.4
# 2015                      12795.3                      8729.4
# 2016                      13148.2                      9098.3
# 2017                      13434.8                      9501.2
# 2018                      13952.1                      9934.3
# 2019                      14016.2                     10203.2
#
#       All Transporation  Worked fm Home    Drove  Carpooled  Walked  \
# 2009            3822714          157174  2962941     396824   85818
# 2010            3845626          167035  2966482     383909  103982
# 2011            3883249          176921  3032187     355426   90716
# 2012            3967188          187750  3067222     393282   87938
# 2013            4018400          182279  3112188     376679   99433
# 2014            4063553          177271  3158348     378398   91217
# 2015            4116194          190819  3190412     374422   96587
# 2016            4150512          208849  3192485     393221  108451
# 2017            4195387          226076  3246194     363154  108589
# 2018            4221015          236778  3235570     384725   93874
# 2019            4291816          247137  3288926     385944   99457
#
#       Public Transportation  Taxi and Bikes
# 2009                 168359           51598
# 2010                 168554           55664
# 2011                 174888           53111
# 2012                 174525           56471
# 2013                 176996           70825
# 2014                 191066           67253
# 2015                 194457           69497
# 2016                 171640           75866
# 2017                 175257           76117
# 2018                 191112           78956
# 2019                 186834           83518

# %%
# Compare the percentage of motor vehicles and public transportation expenditures
# 2009
expenditures_2009 = complete_data.iloc[0, 0:2]
expenditures.plot.pie(autopct='%1.1f%%')
# 2019
expenditures_2019 = complete_data.iloc[10, 0:2]
expenditures.plot.pie(autopct='%1.1f%%')

# Plot Pie Chart
#fig = plt.figure(figsize=(18,10), dpi=1600)
#1 rows 2 cols
#first row, first col
#ax1 = plt.subplot1grid((1,2),(1,0))
#plt.pie(expenditures_2009,colors=("g","r"))
#plt.title('2009')
#first row sec col
#ax1 = plt.subplot1grid((1,2), (0, 1))
#plt.pie(expenditures_2019,colors=("g","r"))
#plt.title('2019')


#Second row first column
#ax1 = plt.subplot2grid((2,2), (1, 0))
#plt.pie(df.a,colors=("g","r"))
#plt.title('InstalledApp')
#second row second column
#ax1 = plt.subplot2grid((2,2), (1, 1))
#plt.pie(df.a,colors=("g","r"))
#plt.title('InstalledApp_2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5c9b1a2932aa> in <module>
#       2 # 2009
#       3 expenditures_2009 = complete_data.iloc[0, 0:2]
# ----> 4 expenditures.plot.pie(autopct='%1.1f%%')
#       5 # 2019
#       6 expenditures_2019 = complete_data.iloc[10, 0:2]
#
# NameError: name 'expenditures' is not defined

# %%
# Compare worked from home and walked to work with all means of transporation
# Create line plot for comparison
all_transportation = complete_data['All Transporation']
worked_fm_home = complete_data['Worked fm Home']
#walked_to_work = complete_data['Walked']
year = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=True)
ax1.plot(year, all_transportation, color='#444444', linestyle='--', label='All Means of Transportation')

ax2.plot(year, worked_fm_home, label='Worked fm Home')
#ax2.plot(year, walked_to_work, label='Walked to Work')

ax1.legend()
ax1.set_title('Population')
ax1.set_xlabel('Years')
ax1.set_ylabel('Population')

ax2.legend()
ax2.set_xlabel('Years')
ax2.set_ylabel('Population')

plt.tight_layout()
plt.show()

# fig.savefig('Compare_Worked fm Home vs. Walk to Work.png')
